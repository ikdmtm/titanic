# %%
# タイタニック生存予測

# %%
# ドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/kaggle/titanic
# Out:
# /content/drive/MyDrive/kaggle/titanic

# %%
import pandas as pd
import numpy as np

# %%
# データの読み込み
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
# データの先頭の５行を表示
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# データの型を調べる
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# nullかどうかを調べてから、その数を調べる
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
x = train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
y = train[['Survived']]

# %%
# one-hotエンコーディングをする
# 展開してそれぞれ0か１を入れる
x = pd.get_dummies(x, columns=['Pclass', 'Sex','Embarked'])
x
# Out:
#       Age  SibSp  Parch     Fare  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0    22.0      1      0   7.2500  ...         1           0           0           1
# 1    38.0      1      0  71.2833  ...         0           1           0           0
# 2    26.0      0      0   7.9250  ...         0           0           0           1
# 3    35.0      1      0  53.1000  ...         0           0           0           1
# 4    35.0      0      0   8.0500  ...         1           0           0           1
# ..    ...    ...    ...      ...  ...       ...         ...         ...         ...
# 886  27.0      0      0  13.0000  ...         1           0           0           1
# 887  19.0      0      0  30.0000  ...         0           0           0           1
# 888   NaN      1      2  23.4500  ...         0           0           0           1
# 889  26.0      0      0  30.0000  ...         1           1           0           0
# 890  32.0      0      0   7.7500  ...         1           0           1           0
#
# [891 rows x 12 columns]

# %%
y = pd.get_dummies(y, columns=['Survived'])
y
# Out:
#      Survived_0  Survived_1
# 0             1           0
# 1             0           1
# 2             0           1
# 3             0           1
# 4             1           0
# ..          ...         ...
# 886           1           0
# 887           0           1
# 888           1           0
# 889           0           1
# 890           1           0
#
# [891 rows x 2 columns]

# %%
# nullの数を調べる
x['Age'].isnull().sum()
# Out:
# 177

# %%
# nullを埋める
x['Age'] = x['Age'].fillna(x['Age'].mean())
# 埋まったか確認
x['Age'].isnull().sum()
# Out:
# 0

# %%
x['Age'].max()
# Out:
# 80.0

# %%
x['Age'] = x['Age']/80
x['Age']
# Out:
# 0      0.275000
# 1      0.475000
# 2      0.325000
# 3      0.437500
# 4      0.437500
#          ...
# 886    0.337500
# 887    0.237500
# 888    0.371239
# 889    0.325000
# 890    0.400000
# Name: Age, Length: 891, dtype: float64

# %%
x['Fare'].max()
# Out:
# 512.3292

# %%
x['Fare'] = x['Fare']/512.3292
x['Fare']
# Out:
# 0      0.014151
# 1      0.139136
# 2      0.015469
# 3      0.103644
# 4      0.015713
#          ...
# 886    0.025374
# 887    0.058556
# 888    0.045771
# 889    0.058556
# 890    0.015127
# Name: Fare, Length: 891, dtype: float64

# %%
# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
# ニューラルネットを試す
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
#from keras.optimizers import Adam

# %%
model = keras.Sequential()
model.add(Dense(20, input_dim=12))
model.add(Activation('sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(2, activation='softmax'))

# %%
model.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x7f9eec113850>,
#  <keras.layers.core.activation.Activation at 0x7f9f640ca210>,
#  <keras.layers.core.dense.Dense at 0x7f9ee80b6610>,
#  <keras.layers.core.dense.Dense at 0x7f9ee80b6e50>]

# %%
#keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.fit(x_train, y_train, batch_size=100, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 7/7 - 1s - loss: 0.6882 - accuracy: 0.6138 - 911ms/epoch - 130ms/step
# Epoch 2/100
# 7/7 - 0s - loss: 0.6811 - accuracy: 0.6138 - 24ms/epoch - 3ms/step
# Epoch 3/100
# 7/7 - 0s - loss: 0.6757 - accuracy: 0.6138 - 12ms/epoch - 2ms/step
# Epoch 4/100
# 7/7 - 0s - loss: 0.6719 - accuracy: 0.6138 - 17ms/epoch - 2ms/step
# Epoch 5/100
# 7/7 - 0s - loss: 0.6690 - accuracy: 0.6138 - 14ms/epoch - 2ms/step
# Epoch 6/100
# 7/7 - 0s - loss: 0.6669 - accuracy: 0.6138 - 13ms/epoch - 2ms/step
# Epoch 7/100
# 7/7 - 0s - loss: 0.6653 - accuracy: 0.6138 - 19ms/epoch - 3ms/step
# Epoch 8/100
# 7/7 - 0s - loss: 0.6639 - accuracy: 0.6138 - 14ms/epoch - 2ms/step
# Epoch 9/100
# 7/7 - 0s - loss: 0.6627 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 10/100
# 7/7 - 0s - loss: 0.6616 - accuracy: 0.6138 - 13ms/epoch - 2ms/step
# Epoch 11/100
# 7/7 - 0s - loss: 0.6604 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 12/100
# 7/7 - 0s - loss: 0.6593 - accuracy: 0.6138 - 17ms/epoch - 2ms/step
# Epoch 13/100
# 7/7 - 0s - loss: 0.6581 - accuracy: 0.6138 - 13ms/epoch - 2ms/step
# Epoch 14/100
# 7/7 - 0s - loss: 0.6569 - accuracy: 0.6138 - 17ms/epoch - 2ms/step
# Epoch 15/100
# 7/7 - 0s - loss: 0.6556 - accuracy: 0.6138 - 18ms/epoch - 3ms/step
# Epoch 16/100
# 7/7 - 0s - loss: 0.6544 - accuracy: 0.6138 - 12ms/epoch - 2ms/step
# Epoch 17/100
# 7/7 - 0s - loss: 0.6530 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 18/100
# 7/7 - 0s - loss: 0.6515 - accuracy: 0.6138 - 10ms/epoch - 1ms/step
# Epoch 19/100
# 7/7 - 0s - loss: 0.6499 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 20/100
# 7/7 - 0s - loss: 0.6483 - accuracy: 0.6138 - 14ms/epoch - 2ms/step
# Epoch 21/100
# 7/7 - 0s - loss: 0.6466 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 22/100
# 7/7 - 0s - loss: 0.6447 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 23/100
# 7/7 - 0s - loss: 0.6427 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 24/100
# 7/7 - 0s - loss: 0.6407 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 25/100
# 7/7 - 0s - loss: 0.6385 - accuracy: 0.6138 - 21ms/epoch - 3ms/step
# Epoch 26/100
# 7/7 - 0s - loss: 0.6362 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 27/100
# 7/7 - 0s - loss: 0.6338 - accuracy: 0.6138 - 15ms/epoch - 2ms/step
# Epoch 28/100
# 7/7 - 0s - loss: 0.6312 - accuracy: 0.6138 - 17ms/epoch - 2ms/step
# Epoch 29/100
# 7/7 - 0s - loss: 0.6284 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 30/100
# 7/7 - 0s - loss: 0.6256 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 31/100
# 7/7 - 0s - loss: 0.6227 - accuracy: 0.6138 - 16ms/epoch - 2ms/step
# Epoch 32/100
# 7/7 - 0s - loss: 0.6196 - accuracy: 0.6168 - 16ms/epoch - 2ms/step
# Epoch 33/100
# 7/7 - 0s - loss: 0.6164 - accuracy: 0.6198 - 16ms/epoch - 2ms/step
# Epoch 34/100
# 7/7 - 0s - loss: 0.6130 - accuracy: 0.6213 - 15ms/epoch - 2ms/step
# Epoch 35/100
# 7/7 - 0s - loss: 0.6097 - accuracy: 0.6272 - 15ms/epoch - 2ms/step
# Epoch 36/100
# 7/7 - 0s - loss: 0.6060 - accuracy: 0.6467 - 16ms/epoch - 2ms/step
# Epoch 37/100
# 7/7 - 0s - loss: 0.6023 - accuracy: 0.6751 - 20ms/epoch - 3ms/step
# Epoch 38/100
# 7/7 - 0s - loss: 0.5985 - accuracy: 0.6901 - 17ms/epoch - 2ms/step
# Epoch 39/100
# 7/7 - 0s - loss: 0.5947 - accuracy: 0.6976 - 17ms/epoch - 2ms/step
# Epoch 40/100
# 7/7 - 0s - loss: 0.5909 - accuracy: 0.7021 - 16ms/epoch - 2ms/step
# Epoch 41/100
# 7/7 - 0s - loss: 0.5868 - accuracy: 0.7126 - 17ms/epoch - 2ms/step
# Epoch 42/100
# 7/7 - 0s - loss: 0.5827 - accuracy: 0.7216 - 17ms/epoch - 2ms/step
# Epoch 43/100
# 7/7 - 0s - loss: 0.5785 - accuracy: 0.7410 - 12ms/epoch - 2ms/step
# Epoch 44/100
# 7/7 - 0s - loss: 0.5744 - accuracy: 0.7635 - 22ms/epoch - 3ms/step
# Epoch 45/100
# 7/7 - 0s - loss: 0.5704 - accuracy: 0.7769 - 11ms/epoch - 2ms/step
# Epoch 46/100
# 7/7 - 0s - loss: 0.5662 - accuracy: 0.7799 - 18ms/epoch - 3ms/step
# Epoch 47/100
# 7/7 - 0s - loss: 0.5622 - accuracy: 0.7784 - 17ms/epoch - 2ms/step
# Epoch 48/100
# 7/7 - 0s - loss: 0.5579 - accuracy: 0.7799 - 16ms/epoch - 2ms/step
# Epoch 49/100
# 7/7 - 0s - loss: 0.5540 - accuracy: 0.7814 - 17ms/epoch - 2ms/step
# Epoch 50/100
# 7/7 - 0s - loss: 0.5500 - accuracy: 0.7844 - 16ms/epoch - 2ms/step
# Epoch 51/100
# 7/7 - 0s - loss: 0.5460 - accuracy: 0.7844 - 18ms/epoch - 3ms/step
# Epoch 52/100
# 7/7 - 0s - loss: 0.5422 - accuracy: 0.7829 - 13ms/epoch - 2ms/step
# Epoch 53/100
# 7/7 - 0s - loss: 0.5385 - accuracy: 0.7799 - 25ms/epoch - 4ms/step
# Epoch 54/100
# 7/7 - 0s - loss: 0.5347 - accuracy: 0.7814 - 13ms/epoch - 2ms/step
# Epoch 55/100
# 7/7 - 0s - loss: 0.5310 - accuracy: 0.7814 - 16ms/epoch - 2ms/step
# Epoch 56/100
# 7/7 - 0s - loss: 0.5277 - accuracy: 0.7814 - 11ms/epoch - 2ms/step
# Epoch 57/100
# 7/7 - 0s - loss: 0.5241 - accuracy: 0.7799 - 17ms/epoch - 2ms/step
# Epoch 58/100
# 7/7 - 0s - loss: 0.5208 - accuracy: 0.7754 - 19ms/epoch - 3ms/step
# Epoch 59/100
# 7/7 - 0s - loss: 0.5176 - accuracy: 0.7740 - 11ms/epoch - 2ms/step
# Epoch 60/100
# 7/7 - 0s - loss: 0.5146 - accuracy: 0.7740 - 16ms/epoch - 2ms/step
# Epoch 61/100
# 7/7 - 0s - loss: 0.5115 - accuracy: 0.7904 - 20ms/epoch - 3ms/step
# Epoch 62/100
# 7/7 - 0s - loss: 0.5087 - accuracy: 0.7919 - 12ms/epoch - 2ms/step
# Epoch 63/100
# 7/7 - 0s - loss: 0.5059 - accuracy: 0.7919 - 14ms/epoch - 2ms/step
# Epoch 64/100
# 7/7 - 0s - loss: 0.5033 - accuracy: 0.7919 - 18ms/epoch - 3ms/step
# Epoch 65/100
# 7/7 - 0s - loss: 0.5007 - accuracy: 0.7934 - 14ms/epoch - 2ms/step
# Epoch 66/100
# 7/7 - 0s - loss: 0.4984 - accuracy: 0.7964 - 17ms/epoch - 2ms/step
# Epoch 67/100
# 7/7 - 0s - loss: 0.4961 - accuracy: 0.7964 - 15ms/epoch - 2ms/step
# Epoch 68/100
# 7/7 - 0s - loss: 0.4938 - accuracy: 0.7979 - 20ms/epoch - 3ms/step
# Epoch 69/100
# 7/7 - 0s - loss: 0.4917 - accuracy: 0.7949 - 16ms/epoch - 2ms/step
# Epoch 70/100
# 7/7 - 0s - loss: 0.4898 - accuracy: 0.7949 - 14ms/epoch - 2ms/step
# Epoch 71/100
# 7/7 - 0s - loss: 0.4879 - accuracy: 0.7964 - 21ms/epoch - 3ms/step
# Epoch 72/100
# 7/7 - 0s - loss: 0.4862 - accuracy: 0.7994 - 16ms/epoch - 2ms/step
# Epoch 73/100
# 7/7 - 0s - loss: 0.4844 - accuracy: 0.7964 - 15ms/epoch - 2ms/step
# Epoch 74/100
# 7/7 - 0s - loss: 0.4826 - accuracy: 0.7964 - 16ms/epoch - 2ms/step
# Epoch 75/100
# 7/7 - 0s - loss: 0.4813 - accuracy: 0.7994 - 17ms/epoch - 2ms/step
# Epoch 76/100
# 7/7 - 0s - loss: 0.4797 - accuracy: 0.8009 - 19ms/epoch - 3ms/step
# Epoch 77/100
# 7/7 - 0s - loss: 0.4783 - accuracy: 0.8024 - 14ms/epoch - 2ms/step
# Epoch 78/100
# 7/7 - 0s - loss: 0.4769 - accuracy: 0.8039 - 16ms/epoch - 2ms/step
# Epoch 79/100
# 7/7 - 0s - loss: 0.4754 - accuracy: 0.8039 - 15ms/epoch - 2ms/step
# Epoch 80/100
# 7/7 - 0s - loss: 0.4743 - accuracy: 0.8039 - 16ms/epoch - 2ms/step
# Epoch 81/100
# 7/7 - 0s - loss: 0.4731 - accuracy: 0.8069 - 13ms/epoch - 2ms/step
# Epoch 82/100
# 7/7 - 0s - loss: 0.4720 - accuracy: 0.8054 - 11ms/epoch - 2ms/step
# Epoch 83/100
# 7/7 - 0s - loss: 0.4709 - accuracy: 0.8069 - 17ms/epoch - 2ms/step
# Epoch 84/100
# 7/7 - 0s - loss: 0.4700 - accuracy: 0.8069 - 22ms/epoch - 3ms/step
# Epoch 85/100
# 7/7 - 0s - loss: 0.4690 - accuracy: 0.8084 - 19ms/epoch - 3ms/step
# Epoch 86/100
# 7/7 - 0s - loss: 0.4682 - accuracy: 0.8009 - 18ms/epoch - 3ms/step
# Epoch 87/100
# 7/7 - 0s - loss: 0.4672 - accuracy: 0.8009 - 15ms/epoch - 2ms/step
# Epoch 88/100
# 7/7 - 0s - loss: 0.4663 - accuracy: 0.8039 - 16ms/epoch - 2ms/step
# Epoch 89/100
# 7/7 - 0s - loss: 0.4655 - accuracy: 0.8054 - 14ms/epoch - 2ms/step
# Epoch 90/100
# 7/7 - 0s - loss: 0.4647 - accuracy: 0.8054 - 16ms/epoch - 2ms/step
# Epoch 91/100
# 7/7 - 0s - loss: 0.4640 - accuracy: 0.8054 - 17ms/epoch - 2ms/step
# Epoch 92/100
# 7/7 - 0s - loss: 0.4632 - accuracy: 0.8054 - 14ms/epoch - 2ms/step
# Epoch 93/100
# 7/7 - 0s - loss: 0.4626 - accuracy: 0.8054 - 24ms/epoch - 3ms/step
# Epoch 94/100
# 7/7 - 0s - loss: 0.4619 - accuracy: 0.8054 - 18ms/epoch - 3ms/step
# Epoch 95/100
# 7/7 - 0s - loss: 0.4612 - accuracy: 0.8054 - 21ms/epoch - 3ms/step
# Epoch 96/100
# 7/7 - 0s - loss: 0.4605 - accuracy: 0.8069 - 16ms/epoch - 2ms/step
# Epoch 97/100
# 7/7 - 0s - loss: 0.4600 - accuracy: 0.8069 - 16ms/epoch - 2ms/step
# Epoch 98/100
# 7/7 - 0s - loss: 0.4593 - accuracy: 0.8069 - 18ms/epoch - 3ms/step
# Epoch 99/100
# 7/7 - 0s - loss: 0.4588 - accuracy: 0.8099 - 20ms/epoch - 3ms/step
# Epoch 100/100
# 7/7 - 0s - loss: 0.4582 - accuracy: 0.8084 - 21ms/epoch - 3ms/step

# %%
# テストデータで評価
model.fit(x_test, y_test, batch_size=100, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 0s - loss: 0.4446 - accuracy: 0.8027 - 11ms/epoch - 4ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 0.4440 - accuracy: 0.8027 - 12ms/epoch - 4ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 0.4432 - accuracy: 0.8072 - 9ms/epoch - 3ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 0.4425 - accuracy: 0.8117 - 14ms/epoch - 5ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.4418 - accuracy: 0.8072 - 13ms/epoch - 4ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.4417 - accuracy: 0.8072 - 11ms/epoch - 4ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.4413 - accuracy: 0.8027 - 9ms/epoch - 3ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.4408 - accuracy: 0.8027 - 7ms/epoch - 2ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.4404 - accuracy: 0.8072 - 10ms/epoch - 3ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.4399 - accuracy: 0.8072 - 6ms/epoch - 2ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.4395 - accuracy: 0.8072 - 6ms/epoch - 2ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.4393 - accuracy: 0.8027 - 9ms/epoch - 3ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.4384 - accuracy: 0.8027 - 9ms/epoch - 3ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.4378 - accuracy: 0.8027 - 8ms/epoch - 3ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.4368 - accuracy: 0.8117 - 6ms/epoch - 2ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.4362 - accuracy: 0.8117 - 6ms/epoch - 2ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.4355 - accuracy: 0.8117 - 13ms/epoch - 4ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.4350 - accuracy: 0.8117 - 8ms/epoch - 3ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.4346 - accuracy: 0.8117 - 8ms/epoch - 3ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.4340 - accuracy: 0.8072 - 11ms/epoch - 4ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.4337 - accuracy: 0.8072 - 7ms/epoch - 2ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.4335 - accuracy: 0.8117 - 8ms/epoch - 3ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.4330 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.4326 - accuracy: 0.8117 - 13ms/epoch - 4ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.4319 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.4320 - accuracy: 0.8161 - 9ms/epoch - 3ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.4316 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.4313 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.4310 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.4308 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.4306 - accuracy: 0.8117 - 7ms/epoch - 2ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 0.4306 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 0.4306 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 0.4304 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 0.4300 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 0.4294 - accuracy: 0.8206 - 10ms/epoch - 3ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 0.4291 - accuracy: 0.8206 - 13ms/epoch - 4ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.4283 - accuracy: 0.8251 - 24ms/epoch - 8ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.4277 - accuracy: 0.8206 - 10ms/epoch - 3ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.4275 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.4272 - accuracy: 0.8161 - 6ms/epoch - 2ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.4269 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.4270 - accuracy: 0.8117 - 8ms/epoch - 3ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.4267 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.4264 - accuracy: 0.8161 - 12ms/epoch - 4ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.4260 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.4258 - accuracy: 0.8117 - 17ms/epoch - 6ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.4252 - accuracy: 0.8161 - 11ms/epoch - 4ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.4250 - accuracy: 0.8161 - 8ms/epoch - 3ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.4248 - accuracy: 0.8161 - 26ms/epoch - 9ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.4245 - accuracy: 0.8161 - 11ms/epoch - 4ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.4242 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.4240 - accuracy: 0.8161 - 13ms/epoch - 4ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.4237 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.4235 - accuracy: 0.8161 - 13ms/epoch - 4ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.4233 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.4234 - accuracy: 0.8161 - 11ms/epoch - 4ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.4232 - accuracy: 0.8161 - 7ms/epoch - 2ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.4231 - accuracy: 0.8161 - 22ms/epoch - 7ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.4227 - accuracy: 0.8161 - 12ms/epoch - 4ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.4225 - accuracy: 0.8161 - 7ms/epoch - 2ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.4223 - accuracy: 0.8161 - 9ms/epoch - 3ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.4221 - accuracy: 0.8161 - 14ms/epoch - 5ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.4217 - accuracy: 0.8161 - 16ms/epoch - 5ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.4214 - accuracy: 0.8161 - 10ms/epoch - 3ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.4211 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.4209 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.4209 - accuracy: 0.8117 - 14ms/epoch - 5ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.4208 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.4207 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.4205 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.4204 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.4200 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.4197 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.4196 - accuracy: 0.8117 - 6ms/epoch - 2ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.4194 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.4191 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.4189 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.4188 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.4186 - accuracy: 0.8161 - 11ms/epoch - 4ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.4184 - accuracy: 0.8161 - 9ms/epoch - 3ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.4182 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.4181 - accuracy: 0.8117 - 7ms/epoch - 2ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.4178 - accuracy: 0.8117 - 7ms/epoch - 2ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.4177 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.4175 - accuracy: 0.8117 - 18ms/epoch - 6ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.4174 - accuracy: 0.8117 - 7ms/epoch - 2ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.4173 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.4170 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.4173 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.4170 - accuracy: 0.8117 - 8ms/epoch - 3ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.4170 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.4168 - accuracy: 0.8117 - 16ms/epoch - 5ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.4168 - accuracy: 0.8117 - 10ms/epoch - 3ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.4167 - accuracy: 0.8117 - 9ms/epoch - 3ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.4165 - accuracy: 0.8117 - 11ms/epoch - 4ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.4163 - accuracy: 0.8117 - 12ms/epoch - 4ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.4161 - accuracy: 0.8117 - 14ms/epoch - 5ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.4160 - accuracy: 0.8117 - 13ms/epoch - 4ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.4159 - accuracy: 0.8117 - 8ms/epoch - 3ms/step

# %%
# submit
x_test = test[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
submit = test[['PassengerId']]

x_test = pd.get_dummies(x_test, columns=['Pclass', 'Sex','Embarked'])
x_test

# Fareのnullを埋める
# nullにFareの平均値を埋め込む
x_test['Fare'] = x_test['Fare'].fillna(x_test['Fare'].mean())
# AgeとFareの正規化
x_test['Age'] = x_test['Age']/70
x_train['Fare'] = x_train['Fare']/263

submit[['Survived_0', 'Survived_1']] = model.predict(x_test)
submit
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:659: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[k] = np.nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#      PassengerId  Survived_0  Survived_1
# 0            892    0.005983    0.994017
# 1            893    0.004738    0.995262
# 2            894    0.004666    0.995334
# 3            895    0.006039    0.993961
# 4            896    0.004296    0.995704
# ..           ...         ...         ...
# 413         1305         NaN         NaN
# 414         1306    0.004166    0.995834
# 415         1307    0.008023    0.991977
# 416         1308         NaN         NaN
# 417         1309         NaN         NaN
#
# [418 rows x 3 columns]

# %%
# nullを0で埋める
submit[['Survived_0', 'Survived_1']] = submit[['Survived_0', 'Survived_1']].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# 0に置き換えられたか確認
submit
# Out:
#      PassengerId  Survived_0  Survived_1
# 0            892    0.005983    0.994017
# 1            893    0.004738    0.995262
# 2            894    0.004666    0.995334
# 3            895    0.006039    0.993961
# 4            896    0.004296    0.995704
# ..           ...         ...         ...
# 413         1305    0.000000    0.000000
# 414         1306    0.004166    0.995834
# 415         1307    0.008023    0.991977
# 416         1308    0.000000    0.000000
# 417         1309    0.000000    0.000000
#
# [418 rows x 3 columns]

# %%
submit['Survived_0'].max()
# Out:
# 0.88519686460495

# %%
submit['Survived_0'].mean()
# Out:
# 0.0064793004972958255

# %%
submit['Survived_0'].max()
# Out:
# 0.88519686460495

# %%
submit['Survived_0'].mean()
# Out:
# 0.0064793004972958255

# %%
# one hot エンコーディングしたい

#for i in range(len(submit['Survived'])):
 # if submit['Survived'][i] > 0.5:
  #  submit['Survived'][i] = 1
  #elif submit['Survived'][i] <= 0.5:
  #  submit['Survived'][i] = 0

#submit['Survived']
#submit

# %%
# csvファイルを作成
submit.to_csv('submission/submit07.csv', index=False)
